# %% [markdown]
# ## Question 7
# Solution from Chaolun Wang

# %%
from IPython.display import Image
Image("figure2.jpg")

# %% [markdown]
# Where $x_j, \gamma_j$ are the m+1 gauss-Legendre nodes and weights respectively. $x_j, \omega_j$ are the n+1 gauss-Laguerre nodes and weights respectively.
#
# The code used to generate the weights and nodes is from online resources:
#
# http://people.sc.fsu.edu/njburkardt/m_src
#
# The exact solution of I was calculated using symbolic tool box, which is 654.6843 with underlying generic alogrithm.
#
# To find m and n so that the estimation of I is within +-0.1 of the ture value, the step number was chosen to be 50, 100, 200, 400, 800 separately, and the estimation of I was plotted with m=n in figure below:

# %%
Image("figure.jpg")

# %% [markdown]
# We can see that m>200, n>200 will guarantee that the estimation of I is between 654.6843+-0.1.
#
# So the estimated value of I is 654.7
