# %% [markdown]
# ### Q9
# Solution from Chaolun

# %% [markdown]
# Denote:
# $$
# x_n=x[n_1,n_2]
# $$
# Where:
# $$
# n=2n_1+7n_2
# $$
#
# Similarly, denote:
# $$
# X_k=X[k_1,k_2]
# $$
# where:
# $$
# k=8k_1+7k_2
# $$
# Based on that we can get the solution:

# %%
from IPython.display import Image
Image(filename='figure.jpg')

# %% [markdown]
# The weight is not clearly shown in the picture above, which are:
#
# for $n_2=0$ the weights are all $\omega^0$
#
# for $n_2=0$ the weights are $\omega^0$, $\omega^1$....$\omega^6$ separately
#
# More information about the Cooley-Tukey FFT Algorithm can refer to Professor Meyer's book about signal processing(page 363, see the attachment), here is a copy of the algorithm:

# %%
Image(filename='figure1.jpg')
